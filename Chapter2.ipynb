# %% [markdown]
#             Chapter no 2
# These are the test programs
#
# 2-1:Simple Message: Store a message in a variable, and then print that
# message.
#
# 2-2: Simple Messages: Store a message in a variable, and print that message.
# Then change the value of your variable to a new message, and print the new
# message.

# %%
#program 2.1
message_arooj="This is a test program"
print(message_arooj)

#program 2.2
message_arooj="Change the value of variable."
print(message_arooj)
message_arooj="This is a new value."
print(message_arooj)
# Out:
# This is a test program
# Change the value of variable.
# This is a new value.
